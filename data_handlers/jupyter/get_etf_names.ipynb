# %%
import json,re,os,sys,random 
import akshare as ak
import tushare as ts

#
ts.set_token('b9b26e60eb1a7ffb3578ae28d43d113c63be23d63b13a9feea0340f4')  # 替换为实际Token
pro = ts.pro_api('b9b26e60eb1a7ffb3578ae28d43d113c63be23d63b13a9feea0340f4')

# %%
pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
# Out:
#         ts_code  symbol     name area industry list_date
# 0     000001.SZ  000001     平安银行   深圳       银行  19910403
# 1     000002.SZ  000002      万科A   深圳     全国地产  19910129
# 2     000004.SZ  000004    *ST国华   深圳     软件服务  19910114
# 3     000006.SZ  000006     深振业A   深圳     区域地产  19920427
# 4     000007.SZ  000007      全新好   深圳     其他商业  19920413
# ...         ...     ...      ...  ...      ...       ...
# 5414  920489.BJ  920489     佳先股份   安徽     化工原料  20200727
# 5415  920682.BJ  920682     球冠电缆   浙江     电气设备  20200727
# 5416  920799.BJ  920799     艾融软件   上海     软件服务  20200727
# 5417  920819.BJ  920819     颖泰生物   北京     农药化肥  20200727
# 5418  689009.SH  689009  九号公司-WD   北京      摩托车  20201029
#
# [5419 rows x 6 columns]

# %%
trade_cal_df = pro.trade_cal(exchange='', start_date='', end_date='', fields='cal_date,is_open')
trade_cal_df
# Out:
#        cal_date  is_open
# 0      20251231        1
# 1      20251230        1
# 2      20251229        1
# 3      20251228        0
# 4      20251227        0
# ...         ...      ...
# 12792  19901223        0
# 12793  19901222        0
# 12794  19901221        1
# 12795  19901220        1
# 12796  19901219        1
#
# [12797 rows x 2 columns]

# %%
df[df.ts_code.str.contains('159995')]
# Out:
# Empty DataFrame
# Columns: [ts_code, symbol, name, area, industry, list_date]
# Index: []

# %%
df[df]

# %%
fund_name_em_df = ak.fund_name_em()
fund_name_em_df
# Out:
#          基金代码              拼音缩写              基金简称      基金类型  \
# 0      000001            HXCZHH            华夏成长混合    混合型-灵活
# 1      000002            HXCZHH        华夏成长混合(后端)    混合型-灵活
# 2      000003          ZHKZZZQA          中海可转债债券A  债券型-混合二级
# 3      000004          ZHKZZZQC          中海可转债债券C  债券型-混合二级
# 4      000005        JSZQXYDQZQ        嘉实增强信用定期债券  债券型-混合一级
# ...       ...               ...               ...       ...
# 24352  970210         ZXJTXXZQC         中信建投欣享债券C   债券型-中短债
# 24353  970211  ZXJTYX12GYCYQZQA  中信建投悠享12个月持有期债券A  债券型-混合一级
# 24354  970212  ZXJTYX12GYCYQZQC  中信建投悠享12个月持有期债券C  债券型-混合一级
# 24355  970213   ZXJTYX6GYCYQZQA   中信建投悦享6个月持有期债券A  债券型-混合一级
# 24356  970214   ZXJTYX6GYCYQZQC   中信建投悦享6个月持有期债券C  债券型-混合一级
#
#                                                   拼音全称
# 0                                HUAXIACHENGZHANGHUNHE
# 1                                HUAXIACHENGZHANGHUNHE
# 2                         ZHONGHAIKEZHUANZHAIZHAIQUANA
# ...

# %%
fund_name_em_df['flag'] = fund_name_em_df['基金简称'].str.contains('半导体')
fund_name_em_df[fund_name_em_df['flag'] == True]
# Out:
#          基金代码                 拼音缩写                 基金简称    基金类型  \
# 5170   007300       GLAZZBDTETFLJA       国联安中证半导体ETF联接A  指数型-股票
# 5171   007301       GLAZZBDTETFLJC       国联安中证半导体ETF联接C  指数型-股票
# 5989   008281   GTCESBDTXPHYETFLJA   国泰CES半导体芯片行业ETF联接A  指数型-股票
# 5990   008282   GTCESBDTXPHYETFLJC   国泰CES半导体芯片行业ETF联接C  指数型-股票
# 6481   008887      HXGZBDTXPETFLJA      华夏国证半导体芯片ETF联接A  指数型-股票
# ...       ...                  ...                  ...     ...
# 23536  560780     GFZZBDTCLSBZTETF     广发中证半导体材料设备主题ETF  指数型-股票
# 23596  561980         ZSZZBDTCYETF         招商中证半导体产业ETF  指数型-股票
# 23622  562590     HXZZBDTCLSBZTETF     华夏中证半导体材料设备主题ETF  指数型-股票
# 23715  588170  HXSZKCBBDTCLSBZTETF  华夏上证科创板半导体材料设备主题ETF  指数型-股票
# 23746  588710                 KBDT                 科半导体  指数型-股票
#
#                                                     拼音全称  flag
# 5170              GUOLIANANZHONGZHENGBANDAOTIETFLIANJIEA  True
# 5171              GUOLIANANZHONGZHENGBANDAOTIETFLIANJIEC  True
# ...

# %%
fund_info_index_em_df = ak.fund_info_index_em(symbol="沪深指数", indicator="增强指数型")
fund_info_index_em_df.基金名称.sample(10)
# Out:
# 429    鹏华上证科创板50成份增强策略ETF发起式联接C
# 421         国泰沪深300增强策略ETF发起联接A
# 437                大成中证500指数增强C
# 575                泓德中证500指数增强A
# 515              国联上证科创板综合指数增强A
# 302             中银中证500指数增强型发起A
# 257           浙商沪深300指数增强(LOF)A
# 441              永赢中证A50指数增强发起A
# 247                博道沪深300指数增强C
# 3               华泰柏瑞中证2000指数增强C
# Name: 基金名称, dtype: object

# %%
fund_info_index_em_df.基金名称.sample(10)
# Out:
# 595           浦银安盛科创板综合指数增强C
# 399    易方达MSCI中国A50互联互通量化增强A
# 189             招商中证800指数增强C
# 610            太平中证A500指数增强C
# 264               华安沪深300增强A
# 322           景顺长城沪深300指数增强A
# 141        工银中证500六个月持有指数增强C
# 449            中欧中证A500指数增强A
# 552           天弘上证科创板综合指数增强C
# 203            海富通沪深300指数增强C
# Name: 基金名称, dtype: object

# %%
# df = pro.stk_mins(ts_code='000001.SZ', freq='1min', start_date='2025-06-28 09:00:00', end_date='2025-7-20 19:00:00')
# df
df = pro.daily(ts_code='300750.SZ', start_date='2025-06-05', end_date='2025-07-04')
df=pro.daily(ts_code='516010.SH', start_date='20250605', end_date='20250704')
df
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount]
# Index: []

# %%
df = pro.stk_mins(ts_code='600000.SH', freq='1min', start_date='2023-08-25 09:00:00', end_date='2023-08-25 19:00:00')
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pro.stk_mins(ts_code='600000.SH', freq='1min', start_date='2023-08-25 09:00:00', end_date='2023-08-25 19:00:00')
#       2 df
#
# File ~/miniconda3/envs/liy_q/lib/python3.10/site-packages/tushare/pro/client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您每天最多访问该接口2次，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。

# %%
df = ts.pro_bar(ts_code='000100.SZ', adj='hfq', start_date='20250701', end_date='20250703',freq='')
df
# Out:
# local variable 'data' referenced before assignment
# local variable 'data' referenced before assignment
# local variable 'data' referenced before assignment
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = ts.pro_bar(ts_code='000100.SZ', adj='hfq', start_date='20250701', end_date='20250703',freq='')
#       2 df
#
# File ~/miniconda3/envs/liy_q/lib/python3.10/site-packages/tushare/pro/data_pro.py:200, in pro_bar(ts_code, api, start_date, end_date, freq, asset, exchange, adj, ma, factors, adjfactor, offset, limit, fields, contract_type, retry_count)
#     198             data = data[f_list]
#     199         return data
# --> 200 raise IOError('ERROR.')
#
# OSError: ERROR.

# %%
int(re.match(r'(\d+)', '1min').group(1))
# Out:
# 1

# %%
df_stock_info = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
df_stock_info[['ts_code','name']].values
# Out:
# array([['000001.SZ', '平安银行'],
#        ['000002.SZ', '万科A'],
#        ['000004.SZ', '*ST国华'],
#        ...,
#        ['920799.BJ', '艾融软件'],
#        ['920819.BJ', '颖泰生物'],
#        ['689009.SH', '九号公司-WD']], shape=(5419, 2), dtype=object)
