# %%
import akshare as ak

# %%
stock_zh_a_hist_tx_df = ak.stock_zh_a_hist_tx(symbol="sz000001", start_date="20250825", end_date="20250826", adjust="hfq")
print(stock_zh_a_hist_tx_df)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#          date    open    close     high      low     amount
# 0  2025-08-25  2262.7  2312.37  2324.42  2259.69  3045088.0
