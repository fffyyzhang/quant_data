# %%
import tushare as ts
import pandas as pd
import time
import os
from tenacity import retry, stop_after_attempt, wait_exponential
import logging
import akshare as ak

# %%
# df = ts.pro_bar(ts_code='000001.SZ', adj='hfq', start_date='20180101', end_date='20181011',freq='15MIN')
ts.set_token('b9b26e60eb1a7ffb3578ae28d43d113c63be23d63b13a9feea0340f4')  # 替换为实际Token
pro = ts.pro_api()

# %%
fund_etf_spot_em_df = ak.fund_etf_spot_em()
fund_etf_spot_em_df.sample(20)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#           代码          名称    最新价  IOPV实时估值  基金折价率    涨跌额   涨跌幅        成交量  \
# 0     159518     标普油气ETF  0.932    0.9295  -0.27  0.031  3.44  2917467.0
# 1     513350     标普油气ETF  0.974    0.9715  -0.26  0.031  3.29  1568686.0
# 2     517110    创新药ETF国泰  0.669    0.6677  -0.19  0.013  1.98   135226.0
# 3     513780  港股创新药50ETF  1.528    1.5360   0.52  0.024  1.60  4819554.0
# 4     516620       影视ETF  1.009    1.0066  -0.24  0.015  1.51   137524.0
# ...      ...         ...    ...       ...    ...    ...   ...        ...
# 1177  159690       矿业ETF  1.119    1.1188  -0.02 -0.022 -1.93    12900.0
# 1178  517400     黄金股票ETF  1.158    1.1563  -0.15 -0.023 -1.95    99509.0
# 1179  516650   有色金属ETF基金  1.101    1.1007  -0.03 -0.024 -2.13    87425.0
# 1180  517520      黄金股ETF  1.454    1.4553   0.09 -0.032 -2.15  1848439.0
# 1181  159321     黄金股票ETF  1.128    1.1272  -0.07 -0.026 -2.25   172334.0
#
# ...

# %%
# Out:
#           代码           名称    最新价  IOPV实时估值  基金折价率    涨跌额   涨跌幅         成交量  \
# 1102  159638      高端装备ETF  0.835    0.8361   0.13 -0.009 -1.07    577868.0
# 1117  513180    恒生科技指数ETF  0.708    0.7077  -0.04 -0.008 -1.12  42993525.0
# 821   159967     创业板成长ETF  0.455    0.4560   0.22 -0.002 -0.44   1854991.0
# 802   560090      证券ETF龙头  1.224    1.2236  -0.03 -0.005 -0.41    520979.0
# 732   159795    智能汽车ETF基金  0.900    0.9004   0.04 -0.003 -0.33      6833.0
# 321   512380    MSCI中国ETF  1.365    1.3636  -0.10  0.001  0.07     35998.0
# 75    560680      消费ETF龙头  0.877    0.8766  -0.05  0.005  0.57    189299.0
# 371   512280  MSCIA股ETF景顺  1.432       NaN    NaN  0.000  0.00         NaN
# 17    159805        传媒ETF  1.233    1.2345   0.12  0.015  1.23    137930.0
# 351   159974      央企创新ETF  1.595    1.5967   0.11  0.000  0.00     13993.0
# 142   512250   中证A50ETF招商  1.078    1.0772  -0.07  0.004  0.37     34060.0
# ...

# %%
fund_etf_spot_em_df[fund_etf_spot_em_df['名称']=='游戏ETF']
fund_etf_spot_em_df[fund_etf_spot_em_df['代码']=='159996']
# Out:
#          代码     名称    最新价  IOPV实时估值  基金折价率    涨跌额   涨跌幅       成交量  \
# 962  159996  家电ETF  1.339     1.339    0.0 -0.009 -0.67  236576.0
#
#               成交额    开盘价  ...   小单净流入-净额  小单净流入-净占比    现手     买一     卖一  \
# 962  3.180854e+07  1.348  ...  1271937.0        4.0  88.0  1.338  1.339
#
#             最新份额        流通市值         总市值       数据日期                      更新时间
# 962  928554848.0  1243334941  1243334941 2025-07-09 2025-07-09 15:35:00+08:00
#
# [1 rows x 37 columns]

# %%
df = pro.fund_daily(ts_code='510330.SH', start_date='20150101', end_date='20250101', fields='trade_date,open,high,low,close,vol,amount')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = pro.fund_daily(ts_code='510330.SH', start_date='20150101', end_date='20250101', fields='trade_date,open,high,low,close,vol,amount')
#
# NameError: name 'pro' is not defined

# %%
fund_etf_category_sina_df = ak.fund_etf_category_sina(symbol="ETF基金")
fund_etf_category_sina_df
# Out:
#             代码          名称    最新价    涨跌额    涨跌幅     买入     卖出     昨收     今开  \
# 0     sz159998      计算机ETF  0.888 -0.005 -0.560  0.887  0.888  0.893  0.893
# 1     sz159997       电子ETF  1.137 -0.005 -0.438  1.134  1.137  1.142  1.143
# 2     sz159996       家电ETF  1.339 -0.009 -0.668  1.338  1.339  1.348  1.348
# 3     sz159995       芯片ETF  1.198 -0.011 -0.910  1.197  1.198  1.209  1.210
# 4     sz159994       5GETF  1.000  0.003  0.301  0.999  1.000  0.997  0.997
# ...        ...         ...    ...    ...    ...    ...    ...    ...    ...
# 1205  sh510050     上证50ETF  2.842 -0.003 -0.105  2.841  2.842  2.845  2.847
# 1206  sh510040  上证180ETF指数  1.025 -0.004 -0.389  1.024  1.026  1.029  1.027
# 1207  sh510030       价值ETF  1.102  0.000  0.000  1.100  1.102  1.102  1.102
# 1208  sh510020      超大盘ETF  3.303 -0.003 -0.091  3.303  3.310  3.306  3.296
# 1209  sh510010    180治理ETF  1.663  0.006  0.362  1.655  1.663  1.657  1.658
#
#          最高     最低        成交量         成交额
# ...
